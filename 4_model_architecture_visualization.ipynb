# %%
import os
import visualkeras
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.applications import VGG16, ResNet50V2, InceptionResNetV2, MobileNetV2, EfficientNetB3

# %% [markdown]
# # Load models
# * Transfer Learning models: VVG16, ResNet50v2, InceptionResNetv2 and MobileNetv2
# * Simple CNN

# %%
vgg16_custom = tf.keras.models.load_model('Saved_models_and_history/custom_vgg16.keras')
ResNet50v2_custom = tf.keras.models.load_model('Saved_models_and_history/ResNet50v2_custom.keras')
InceptionResNetv2_custom = tf.keras.models.load_model('Saved_models_and_history/InceptionResNetv2_custom.keras')
MobileNetv2_custom = tf.keras.models.load_model('Saved_models_and_history/MobileNetv2_custom.keras')
simple_CNN = tf.keras.models.load_model('Saved_models_and_history/simple_CNN.keras')
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3060 Ti, compute capability 8.6

# %% [markdown]
# # Plot and visualise models

# %% [markdown]
# ## VGG16

# %% [markdown]
# ### Original VGG16

# %%
visualkeras.layered_view(VGG16(weights='imagenet', include_top = False, input_shape=(256,256,3)),
                         legend = True, to_file='images/VGG16.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=1028x1402>

# %% [markdown]
# ### Plot model

# %%
plot_model(vgg16_custom,
           to_file= 'images/model_plot_vgg16_custom.png',
           show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# ### TL-VGG16 visualization

# %%
visualkeras.layered_view(vgg16_custom, legend = True, to_file='images/vgg16_custom.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=776x1402>

# %% [markdown]
# ## ResNet50v2

# %% [markdown]
# ### Original ResNet50v2

# %%
visualkeras.layered_view(ResNet50V2(weights='imagenet', include_top = False, input_shape=(256,256,3)),
                         legend = True, to_file='images/ResNet50V2.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=11962x1434>

# %% [markdown]
# ### Plot model

# %%
plot_model(ResNet50v2_custom,
           to_file= 'images/model_plot_ResNet50v2_custom.png',
           show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# ### TL-VGG16 visualization

# %%
visualkeras.layered_view(ResNet50v2_custom, legend = True, to_file='images/ResNet50v2_custom.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=929x1402>

# %% [markdown]
# ## InceptionResNetV2

# %% [markdown]
# ### Original InceptionResNetV2

# %%
visualkeras.layered_view(InceptionResNetV2(weights='imagenet', include_top = False, input_shape=(256,256,3)),
                         legend = True, to_file='images/InceptionResNetV2.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=36710x1402>

# %% [markdown]
# ### Plot model

# %%
plot_model(InceptionResNetv2_custom,
           to_file= 'images/model_plot_InceptionResNetv2_custom.png',
           show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# ### TL-VGG16 visualization

# %%
visualkeras.layered_view(InceptionResNetv2_custom, legend = True, to_file='images/InceptionResNetv2_custom.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=878x1402>

# %% [markdown]
# ## MobileNetV2

# %% [markdown]
# ### Original MobileNetV2

# %%
visualkeras.layered_view(MobileNetV2(weights='imagenet', include_top = False, input_shape=(256,256,3)),
                         legend = True, to_file='images/MobileNetV2.png')
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# <PIL.Image.Image image mode=RGBA size=7679x1402>

# %% [markdown]
# ### Plot model

# %%
plot_model(MobileNetv2_custom,
           to_file= 'images/model_plot_MobileNetv2_custom.png',
           show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# ### TL-VGG16 visualization

# %%
visualkeras.layered_view(MobileNetv2_custom, legend = True, to_file='images/MobileNetv2_custom.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=852x1402>

# %% [markdown]
# ## Simple CNN

# %% [markdown]
# ### Plot model

# %%
plot_model(simple_CNN,
           to_file= 'images/simple_CNN.png',
           show_shapes=True,
           show_layer_names=True)

# %% [markdown]
# ### TL-VGG16 visualization

# %%
visualkeras.layered_view(simple_CNN, legend = True, to_file='images/simple_CNN.png')
# Out:
# <PIL.Image.Image image mode=RGBA size=934x1391>
