# %% [markdown]
# Load module for work with hdf5 files

# %%
import os
import cv2
import h5py
import numpy as np

# %% [markdown]
# Download dataset from web and unzip

# %%
#Dataset from
#https://www.kaggle.com/datasets/thomasdubail/brain-tumors-256x256/
#https://www.kaggle.com/datasets/sartajbhuvaji/brain-tumor-classification-mri/data

# %% [markdown]
# This function check in each folder of the classes anf get the total amount of images
# Necessary to predefine the size of the hdf5 file

# %%
def count_images_in_directory(directory):
    image_count = 0
    for root, _, files in os.walk(directory):
        for file in files:
            if file.lower().endswith('.jpg'):
                image_count += 1
    return image_count

# %% [markdown]
#  This function receives the path to the folder with the data, also receives the name in which the hdf5 file is going to be saved
#  The hdf5 file store the images in a random way in a dataset of images
#  Also saves its associated class in a dataset of labels
#  Notice that the output h5 file is going to be saved in the folder Dataset

# %%
def image_hdf5_from_directory(pathfile, name_hdf5_file = 'dataset.h5'):
    output_hdf5 = 'Dataset/'+name_hdf5_file

    path_to_each_folder = [os.path.join(pathfile, name) for name in os.listdir(pathfile)]

    # Initialize the HDF5 file
    with h5py.File(output_hdf5, 'w') as hdf5_file:

      ammount_images = count_images_in_directory(pathfile)

      # Create datasets for images and labels
      image_dataset = hdf5_file.create_dataset("images", (ammount_images, 256, 256, 3), dtype='uint8')
      label_dataset = hdf5_file.create_dataset("labels", (ammount_images,), dtype='int')

      # Create lists to keep track of the order of images
      #image_indices = list(range(4000))
      image_indices = np.arange(ammount_images)

      # Shuffle the order in which images will be added
      #random.shuffle(image_indices)
      np.random.shuffle(image_indices)

      # Function to add image and label to the dataset
      def add_image(image, label, index):
          image_dataset[index] = image
          label_dataset[index] = label

      i = 0
      for class_label, folder_path in enumerate(path_to_each_folder):
        for filename in os.listdir(folder_path):
            if filename.endswith(('.jpg')):
                file_path = os.path.join(folder_path, filename)
                image = cv2.imread(file_path)
                image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
                image = cv2.resize(image, (256, 256))

                if image is not None:
                  index = image_indices[i]
                  add_image(image, class_label, index)
                  print('Saved image', i, 'to h5 file in', index, 'position')
                  i+=1

# %% [markdown]
# Call the previous function, we specify the path to the training data folder and also specify the name 'dataset_training.h5'

# %%
image_hdf5_from_directory('Dataset/Training', name_hdf5_file = 'dataset_training.h5')
# Out:
# Saved image 0 to h5 file in 1547 position
# Saved image 1 to h5 file in 1250 position
# Saved image 2 to h5 file in 819 position
# Saved image 3 to h5 file in 2215 position
# Saved image 4 to h5 file in 1148 position
# Saved image 5 to h5 file in 1402 position
# Saved image 6 to h5 file in 805 position
# Saved image 7 to h5 file in 2152 position
# Saved image 8 to h5 file in 1654 position
# Saved image 9 to h5 file in 887 position
# Saved image 10 to h5 file in 1443 position
# Saved image 11 to h5 file in 1156 position
# Saved image 12 to h5 file in 1753 position
# Saved image 13 to h5 file in 606 position
# Saved image 14 to h5 file in 167 position
# Saved image 15 to h5 file in 1995 position
# Saved image 16 to h5 file in 7 position
# Saved image 17 to h5 file in 943 position
# Saved image 18 to h5 file in 2012 position
# Saved image 19 to h5 file in 2596 position
# Saved image 20 to h5 file in 2232 position
# Saved image 21 to h5 file in 1269 position
# Saved image 22 to h5 file in 1397 position
# Saved image 23 to h5 file in 2673 position
# Saved image 24 to h5 file in 2854 position
# Saved image 25 to h5 file in 1315 position
# Saved image 26 to h5 file in 1808 position
# Saved image 27 to h5 file in 1517 position
# Saved image 28 to h5 file in 1646 position
# Saved image 29 to h5 file in 2390 position
# Saved image 30 to h5 file in 2424 position
# Saved image 31 to h5 file in 1565 position
# Saved image 32 to h5 file in 1923 position
# Saved image 33 to h5 file in 876 position
# Saved image 34 to h5 file in 1457 position
# Saved image 35 to h5 file in 2558 position
# Saved image 36 to h5 file in 1801 position
# Saved image 37 to h5 file in 1203 position
# Saved image 38 to h5 file in 297 position
# Saved image 39 to h5 file in 119 position
# Saved image 40 to h5 file in 903 position
# Saved image 41 to h5 file in 2395 position
# Saved image 42 to h5 file in 2805 position
# Saved image 43 to h5 file in 2150 position
# Saved image 44 to h5 file in 1257 position
# Saved image 45 to h5 file in 182 position
# Saved image 46 to h5 file in 1002 position
# Saved image 47 to h5 file in 2821 position
# Saved image 48 to h5 file in 2010 position
# Saved image 49 to h5 file in 2304 position
# Saved image 50 to h5 file in 2500 position
# Saved image 51 to h5 file in 597 position
# Saved image 52 to h5 file in 1287 position
# Saved image 53 to h5 file in 1206 position
# Saved image 54 to h5 file in 31 position
# Saved image 55 to h5 file in 9 position
# Saved image 56 to h5 file in 19 position
# Saved image 57 to h5 file in 1448 position
# Saved image 58 to h5 file in 1968 position
# Saved image 59 to h5 file in 845 position
# Saved image 60 to h5 file in 2117 position
# Saved image 61 to h5 file in 349 position
# Saved image 62 to h5 file in 1951 position
# Saved image 63 to h5 file in 2427 position
# Saved image 64 to h5 file in 2193 position
# Saved image 65 to h5 file in 1059 position
# Saved image 66 to h5 file in 2368 position
# Saved image 67 to h5 file in 2651 position
# Saved image 68 to h5 file in 2145 position
# Saved image 69 to h5 file in 649 position
# Saved image 70 to h5 file in 2171 position
# Saved image 71 to h5 file in 1188 position
# Saved image 72 to h5 file in 2574 position
# Saved image 73 to h5 file in 1450 position
# Saved image 74 to h5 file in 1873 position
# Saved image 75 to h5 file in 432 position
# Saved image 76 to h5 file in 2360 position
# Saved image 77 to h5 file in 2265 position
# Saved image 78 to h5 file in 1373 position
# Saved image 79 to h5 file in 1863 position
# Saved image 80 to h5 file in 2240 position
# Saved image 81 to h5 file in 1478 position
# Saved image 82 to h5 file in 1185 position
# Saved image 83 to h5 file in 1355 position
# Saved image 84 to h5 file in 2383 position
# Saved image 85 to h5 file in 665 position
# Saved image 86 to h5 file in 355 position
# Saved image 87 to h5 file in 1482 position
# Saved image 88 to h5 file in 2670 position
# Saved image 89 to h5 file in 2850 position
# Saved image 90 to h5 file in 321 position
# Saved image 91 to h5 file in 501 position
# Saved image 92 to h5 file in 2523 position
# Saved image 93 to h5 file in 1290 position
# Saved image 94 to h5 file in 947 position
# Saved image 95 to h5 file in 2286 position
# Saved image 96 to h5 file in 410 position
# Saved image 97 to h5 file in 2448 position
# Saved image 98 to h5 file in 1461 position
# Saved image 99 to h5 file in 2440 position
# Saved image 100 to h5 file in 854 position
# Saved image 101 to h5 file in 719 position
# Saved image 102 to h5 file in 299 position
# Saved image 103 to h5 file in 157 position
# Saved image 104 to h5 file in 2676 position
# Saved image 105 to h5 file in 1103 position
# Saved image 106 to h5 file in 1933 position
# Saved image 107 to h5 file in 193 position
# Saved image 108 to h5 file in 1649 position
# Saved image 109 to h5 file in 2027 position
# Saved image 110 to h5 file in 1098 position
# Saved image 111 to h5 file in 2081 position
# Saved image 112 to h5 file in 787 position
# Saved image 113 to h5 file in 32 position
# Saved image 114 to h5 file in 49 position
# Saved image 115 to h5 file in 2837 position
# Saved image 116 to h5 file in 2112 position
# Saved image 117 to h5 file in 1301 position
# Saved image 118 to h5 file in 677 position
# Saved image 119 to h5 file in 2791 position
# Saved image 120 to h5 file in 2126 position
# Saved image 121 to h5 file in 1656 position
# Saved image 122 to h5 file in 1504 position
# Saved image 123 to h5 file in 98 position
# Saved image 124 to h5 file in 1781 position
# Saved image 125 to h5 file in 1267 position
# Saved image 126 to h5 file in 1334 position
# Saved image 127 to h5 file in 1479 position
# Saved image 128 to h5 file in 1896 position
# Saved image 129 to h5 file in 1009 position
# Saved image 130 to h5 file in 1409 position
# Saved image 131 to h5 file in 1572 position
# Saved image 132 to h5 file in 2585 position
# Saved image 133 to h5 file in 1618 position
# Saved image 134 to h5 file in 1901 position
# Saved image 135 to h5 file in 590 position
# Saved image 136 to h5 file in 33 position
# Saved image 137 to h5 file in 2244 position
# Saved image 138 to h5 file in 521 position
# Saved image 139 to h5 file in 2324 position
# Saved image 140 to h5 file in 588 position
# Saved image 141 to h5 file in 1164 position
# Saved image 142 to h5 file in 532 position
# Saved image 143 to h5 file in 2531 position
# Saved image 144 to h5 file in 561 position
# Saved image 145 to h5 file in 225 position
# Saved image 146 to h5 file in 2763 position
# Saved image 147 to h5 file in 2031 position
# Saved image 148 to h5 file in 473 position
# Saved image 149 to h5 file in 2608 position
# Saved image 150 to h5 file in 1859 position
# Saved image 151 to h5 file in 2827 position
# Saved image 152 to h5 file in 506 position
# Saved image 153 to h5 file in 1135 position
# Saved image 154 to h5 file in 285 position
# Saved image 155 to h5 file in 2297 position
# Saved image 156 to h5 file in 120 position
# Saved image 157 to h5 file in 2813 position
# Saved image 158 to h5 file in 107 position
# Saved image 159 to h5 file in 2335 position
# Saved image 160 to h5 file in 861 position
# Saved image 161 to h5 file in 1785 position
# Saved image 162 to h5 file in 2375 position
# Saved image 163 to h5 file in 1350 position
# Saved image 164 to h5 file in 262 position
# Saved image 165 to h5 file in 1514 position
# Saved image 166 to h5 file in 2692 position
# Saved image 167 to h5 file in 2476 position
# Saved image 168 to h5 file in 1268 position
# Saved image 169 to h5 file in 971 position
# Saved image 170 to h5 file in 1227 position
# Saved image 171 to h5 file in 387 position
# Saved image 172 to h5 file in 1252 position
# Saved image 173 to h5 file in 795 position
# Saved image 174 to h5 file in 1718 position
# Saved image 175 to h5 file in 691 position
# Saved image 176 to h5 file in 2309 position
# Saved image 177 to h5 file in 2665 position
# Saved image 178 to h5 file in 115 position
# Saved image 179 to h5 file in 468 position
# Saved image 180 to h5 file in 1150 position
# Saved image 181 to h5 file in 411 position
# Saved image 182 to h5 file in 2261 position
# Saved image 183 to h5 file in 1642 position
# Saved image 184 to h5 file in 954 position
# Saved image 185 to h5 file in 1712 position
# Saved image 186 to h5 file in 1029 position
# Saved image 187 to h5 file in 430 position
# Saved image 188 to h5 file in 2639 position
# Saved image 189 to h5 file in 543 position
# Saved image 190 to h5 file in 2013 position
# Saved image 191 to h5 file in 2491 position
# Saved image 192 to h5 file in 239 position
# Saved image 193 to h5 file in 792 position
# Saved image 194 to h5 file in 1791 position
# Saved image 195 to h5 file in 2201 position
# Saved image 196 to h5 file in 328 position
# Saved image 197 to h5 file in 2733 position
# Saved image 198 to h5 file in 84 position
# Saved image 199 to h5 file in 281 position
# Saved image 200 to h5 file in 782 position
# Saved image 201 to h5 file in 989 position
# Saved image 202 to h5 file in 917 position
# Saved image 203 to h5 file in 1307 position
# Saved image 204 to h5 file in 1296 position
# Saved image 205 to h5 file in 1736 position
# Saved image 206 to h5 file in 593 position
# Saved image 207 to h5 file in 999 position
# Saved image 208 to h5 file in 936 position
# Saved image 209 to h5 file in 1909 position
# Saved image 210 to h5 file in 2236 position
# Saved image 211 to h5 file in 1474 position
# Saved image 212 to h5 file in 1359 position
# Saved image 213 to h5 file in 117 position
# Saved image 214 to h5 file in 2459 position
# Saved image 215 to h5 file in 2548 position
# Saved image 216 to h5 file in 1739 position
# Saved image 217 to h5 file in 2730 position
# Saved image 218 to h5 file in 2452 position
# Saved image 219 to h5 file in 99 position
# Saved image 220 to h5 file in 334 position
# Saved image 221 to h5 file in 2096 position
# Saved image 222 to h5 file in 1944 position
# Saved image 223 to h5 file in 1219 position
# Saved image 224 to h5 file in 1526 position
# Saved image 225 to h5 file in 480 position
# Saved image 226 to h5 file in 1266 position
# Saved image 227 to h5 file in 2046 position
# Saved image 228 to h5 file in 1067 position
# Saved image 229 to h5 file in 116 position
# Saved image 230 to h5 file in 2792 position
# Saved image 231 to h5 file in 1839 position
# Saved image 232 to h5 file in 1163 position
# Saved image 233 to h5 file in 2255 position
# Saved image 234 to h5 file in 1500 position
# Saved image 235 to h5 file in 1248 position
# Saved image 236 to h5 file in 1472 position
# Saved image 237 to h5 file in 1878 position
# Saved image 238 to h5 file in 981 position
# Saved image 239 to h5 file in 434 position
# Saved image 240 to h5 file in 465 position
# Saved image 241 to h5 file in 1660 position
# Saved image 242 to h5 file in 1291 position
# Saved image 243 to h5 file in 1686 position
# Saved image 244 to h5 file in 227 position
# Saved image 245 to h5 file in 2738 position
# Saved image 246 to h5 file in 1237 position
# Saved image 247 to h5 file in 166 position
# Saved image 248 to h5 file in 291 position
# Saved image 249 to h5 file in 1862 position
# Saved image 250 to h5 file in 2290 position
# Saved image 251 to h5 file in 547 position
# Saved image 252 to h5 file in 957 position
# Saved image 253 to h5 file in 982 position
# Saved image 254 to h5 file in 1606 position
# Saved image 255 to h5 file in 1388 position
# Saved image 256 to h5 file in 815 position
# Saved image 257 to h5 file in 2565 position
# Saved image 258 to h5 file in 1187 position
# Saved image 259 to h5 file in 548 position
# Saved image 260 to h5 file in 730 position
# Saved image 261 to h5 file in 256 position
# Saved image 262 to h5 file in 296 position
# Saved image 263 to h5 file in 2298 position
# Saved image 264 to h5 file in 1588 position
# Saved image 265 to h5 file in 2575 position
# Saved image 266 to h5 file in 2635 position
# Saved image 267 to h5 file in 1033 position
# Saved image 268 to h5 file in 2234 position
# Saved image 269 to h5 file in 2835 position
# Saved image 270 to h5 file in 464 position
# Saved image 271 to h5 file in 421 position
# Saved image 272 to h5 file in 1221 position
# Saved image 273 to h5 file in 394 position
# Saved image 274 to h5 file in 209 position
# Saved image 275 to h5 file in 2708 position
# Saved image 276 to h5 file in 2376 position
# Saved image 277 to h5 file in 743 position
# Saved image 278 to h5 file in 190 position
# Saved image 279 to h5 file in 556 position
# Saved image 280 to h5 file in 2325 position
# Saved image 281 to h5 file in 666 position
# Saved image 282 to h5 file in 960 position
# Saved image 283 to h5 file in 1014 position
# Saved image 284 to h5 file in 2509 position
# Saved image 285 to h5 file in 2047 position
# Saved image 286 to h5 file in 2556 position
# Saved image 287 to h5 file in 2058 position
# Saved image 288 to h5 file in 292 position
# Saved image 289 to h5 file in 767 position
# Saved image 290 to h5 file in 1108 position
# Saved image 291 to h5 file in 2361 position
# Saved image 292 to h5 file in 1798 position
# Saved image 293 to h5 file in 223 position
# Saved image 294 to h5 file in 488 position
# Saved image 295 to h5 file in 2060 position
# Saved image 296 to h5 file in 539 position
# Saved image 297 to h5 file in 1969 position
# Saved image 298 to h5 file in 1339 position
# Saved image 299 to h5 file in 535 position
# Saved image 300 to h5 file in 860 position
# Saved image 301 to h5 file in 2403 position
# Saved image 302 to h5 file in 2820 position
# Saved image 303 to h5 file in 2493 position
# Saved image 304 to h5 file in 2490 position
# Saved image 305 to h5 file in 946 position
# Saved image 306 to h5 file in 1715 position
# Saved image 307 to h5 file in 808 position
# Saved image 308 to h5 file in 2020 position
# Saved image 309 to h5 file in 1844 position
# Saved image 310 to h5 file in 2655 position
# Saved image 311 to h5 file in 317 position
# Saved image 312 to h5 file in 1912 position
# Saved image 313 to h5 file in 2494 position
# Saved image 314 to h5 file in 1653 position
# Saved image 315 to h5 file in 598 position
# Saved image 316 to h5 file in 73 position
# Saved image 317 to h5 file in 2417 position
# Saved image 318 to h5 file in 959 position
# Saved image 319 to h5 file in 611 position
# Saved image 320 to h5 file in 55 position
# Saved image 321 to h5 file in 1360 position
# Saved image 322 to h5 file in 1571 position
# Saved image 323 to h5 file in 11 position
# Saved image 324 to h5 file in 1101 position
# Saved image 325 to h5 file in 594 position
# Saved image 326 to h5 file in 896 position
# Saved image 327 to h5 file in 1390 position
# Saved image 328 to h5 file in 134 position
# Saved image 329 to h5 file in 18 position
# Saved image 330 to h5 file in 2380 position
# Saved image 331 to h5 file in 2217 position
# Saved image 332 to h5 file in 2633 position
# Saved image 333 to h5 file in 1645 position
# Saved image 334 to h5 file in 1704 position
# Saved image 335 to h5 file in 1452 position
# Saved image 336 to h5 file in 2063 position
# Saved image 337 to h5 file in 1232 position
# Saved image 338 to h5 file in 2519 position
# Saved image 339 to h5 file in 2415 position
# Saved image 340 to h5 file in 170 position
# Saved image 341 to h5 file in 204 position
# Saved image 342 to h5 file in 127 position
# Saved image 343 to h5 file in 1371 position
# Saved image 344 to h5 file in 417 position
# Saved image 345 to h5 file in 1980 position
# Saved image 346 to h5 file in 1114 position
# Saved image 347 to h5 file in 1722 position
# Saved image 348 to h5 file in 2445 position
# Saved image 349 to h5 file in 540 position
# Saved image 350 to h5 file in 2529 position
# Saved image 351 to h5 file in 692 position
# Saved image 352 to h5 file in 662 position
# Saved image 353 to h5 file in 759 position
# Saved image 354 to h5 file in 40 position
# Saved image 355 to h5 file in 250 position
# Saved image 356 to h5 file in 453 position
# Saved image 357 to h5 file in 2463 position
# Saved image 358 to h5 file in 241 position
# Saved image 359 to h5 file in 2599 position
# Saved image 360 to h5 file in 2610 position
# Saved image 361 to h5 file in 2744 position
# Saved image 362 to h5 file in 1093 position
# Saved image 363 to h5 file in 2602 position
# Saved image 364 to h5 file in 2693 position
# Saved image 365 to h5 file in 374 position
# Saved image 366 to h5 file in 2808 position
# Saved image 367 to h5 file in 1849 position
# Saved image 368 to h5 file in 2649 position
# Saved image 369 to h5 file in 1971 position
# Saved image 370 to h5 file in 2264 position
# Saved image 371 to h5 file in 1105 position
# Saved image 372 to h5 file in 718 position
# Saved image 373 to h5 file in 2863 position
# Saved image 374 to h5 file in 2752 position
# Saved image 375 to h5 file in 2299 position
# Saved image 376 to h5 file in 2119 position
# Saved image 377 to h5 file in 1417 position
# Saved image 378 to h5 file in 668 position
# Saved image 379 to h5 file in 2220 position
# Saved image 380 to h5 file in 452 position
# Saved image 381 to h5 file in 2385 position
# Saved image 382 to h5 file in 1672 position
# Saved image 383 to h5 file in 1011 position
# Saved image 384 to h5 file in 426 position
# Saved image 385 to h5 file in 2714 position
# Saved image 386 to h5 file in 1629 position
# Saved image 387 to h5 file in 603 position
# Saved image 388 to h5 file in 1052 position
# Saved image 389 to h5 file in 1637 position
# Saved image 390 to h5 file in 690 position
# Saved image 391 to h5 file in 620 position
# Saved image 392 to h5 file in 2473 position
# Saved image 393 to h5 file in 1322 position
# Saved image 394 to h5 file in 534 position
# Saved image 395 to h5 file in 2250 position
# Saved image 396 to h5 file in 2757 position
# Saved image 397 to h5 file in 449 position
# Saved image 398 to h5 file in 1885 position
# Saved image 399 to h5 file in 1308 position
# Saved image 400 to h5 file in 1285 position
# Saved image 401 to h5 file in 234 position
# Saved image 402 to h5 file in 420 position
# Saved image 403 to h5 file in 1833 position
# Saved image 404 to h5 file in 950 position
# Saved image 405 to h5 file in 2030 position
# Saved image 406 to h5 file in 2231 position
# Saved image 407 to h5 file in 1264 position
# Saved image 408 to h5 file in 79 position
# Saved image 409 to h5 file in 2206 position
# Saved image 410 to h5 file in 2008 position
# Saved image 411 to h5 file in 2273 position
# Saved image 412 to h5 file in 78 position
# Saved image 413 to h5 file in 1036 position
# Saved image 414 to h5 file in 1178 position
# Saved image 415 to h5 file in 1924 position
# Saved image 416 to h5 file in 247 position
# Saved image 417 to h5 file in 2085 position
# Saved image 418 to h5 file in 689 position
# Saved image 419 to h5 file in 664 position
# Saved image 420 to h5 file in 2720 position
# Saved image 421 to h5 file in 642 position
# Saved image 422 to h5 file in 1111 position
# Saved image 423 to h5 file in 1778 position
# Saved image 424 to h5 file in 318 position
# Saved image 425 to h5 file in 1289 position
# Saved image 426 to h5 file in 278 position
# Saved image 427 to h5 file in 158 position
# Saved image 428 to h5 file in 2082 position
# Saved image 429 to h5 file in 273 position
# Saved image 430 to h5 file in 2011 position
# Saved image 431 to h5 file in 2866 position
# Saved image 432 to h5 file in 2468 position
# Saved image 433 to h5 file in 2365 position
# Saved image 434 to h5 file in 953 position
# Saved image 435 to h5 file in 2358 position
# Saved image 436 to h5 file in 1662 position
# Saved image 437 to h5 file in 1434 position
# Saved image 438 to h5 file in 146 position
# Saved image 439 to h5 file in 8 position
# Saved image 440 to h5 file in 1596 position
# Saved image 441 to h5 file in 1330 position
# Saved image 442 to h5 file in 1800 position
# Saved image 443 to h5 file in 1465 position
# Saved image 444 to h5 file in 2762 position
# Saved image 445 to h5 file in 474 position
# Saved image 446 to h5 file in 2630 position
# Saved image 447 to h5 file in 2052 position
# Saved image 448 to h5 file in 582 position
# Saved image 449 to h5 file in 975 position
# Saved image 450 to h5 file in 750 position
# Saved image 451 to h5 file in 739 position
# Saved image 452 to h5 file in 1638 position
# Saved image 453 to h5 file in 1380 position
# Saved image 454 to h5 file in 2387 position
# Saved image 455 to h5 file in 206 position
# Saved image 456 to h5 file in 746 position
# Saved image 457 to h5 file in 1451 position
# Saved image 458 to h5 file in 2728 position
# Saved image 459 to h5 file in 62 position
# Saved image 460 to h5 file in 2497 position
# Saved image 461 to h5 file in 2843 position
# Saved image 462 to h5 file in 2717 position
# Saved image 463 to h5 file in 1244 position
# Saved image 464 to h5 file in 741 position
# Saved image 465 to h5 file in 2033 position
# Saved image 466 to h5 file in 282 position
# Saved image 467 to h5 file in 870 position
# Saved image 468 to h5 file in 75 position
# Saved image 469 to h5 file in 1356 position
# Saved image 470 to h5 file in 740 position
# Saved image 471 to h5 file in 2345 position
# Saved image 472 to h5 file in 1230 position
# Saved image 473 to h5 file in 161 position
# Saved image 474 to h5 file in 1732 position
# Saved image 475 to h5 file in 656 position
# Saved image 476 to h5 file in 537 position
# Saved image 477 to h5 file in 2394 position
# Saved image 478 to h5 file in 1575 position
# Saved image 479 to h5 file in 2179 position
# Saved image 480 to h5 file in 2713 position
# Saved image 481 to h5 file in 1124 position
# Saved image 482 to h5 file in 1379 position
# Saved image 483 to h5 file in 2238 position
# Saved image 484 to h5 file in 699 position
# Saved image 485 to h5 file in 1209 position
# Saved image 486 to h5 file in 2572 position
# Saved image 487 to h5 file in 915 position
# Saved image 488 to h5 file in 952 position
# Saved image 489 to h5 file in 1083 position
# Saved image 490 to h5 file in 566 position
# Saved image 491 to h5 file in 20 position
# Saved image 492 to h5 file in 542 position
# Saved image 493 to h5 file in 283 position
# Saved image 494 to h5 file in 541 position
# Saved image 495 to h5 file in 1251 position
# Saved image 496 to h5 file in 1256 position
# Saved image 497 to h5 file in 1063 position
# Saved image 498 to h5 file in 1544 position
# Saved image 499 to h5 file in 2832 position
# Saved image 500 to h5 file in 948 position
# Saved image 501 to h5 file in 2105 position
# Saved image 502 to h5 file in 2793 position
# Saved image 503 to h5 file in 1846 position
# Saved image 504 to h5 file in 2619 position
# Saved image 505 to h5 file in 59 position
# Saved image 506 to h5 file in 2378 position
# Saved image 507 to h5 file in 2106 position
# Saved image 508 to h5 file in 1519 position
# Saved image 509 to h5 file in 1035 position
# Saved image 510 to h5 file in 731 position
# Saved image 511 to h5 file in 601 position
# Saved image 512 to h5 file in 1024 position
# Saved image 513 to h5 file in 604 position
# Saved image 514 to h5 file in 1222 position
# Saved image 515 to h5 file in 2684 position
# Saved image 516 to h5 file in 409 position
# Saved image 517 to h5 file in 791 position
# Saved image 518 to h5 file in 827 position
# Saved image 519 to h5 file in 1213 position
# Saved image 520 to h5 file in 2090 position
# Saved image 521 to h5 file in 197 position
# Saved image 522 to h5 file in 1038 position
# Saved image 523 to h5 file in 2410 position
# Saved image 524 to h5 file in 203 position
# Saved image 525 to h5 file in 1233 position
# Saved image 526 to h5 file in 2019 position
# Saved image 527 to h5 file in 2100 position
# Saved image 528 to h5 file in 932 position
# Saved image 529 to h5 file in 1131 position
# Saved image 530 to h5 file in 2769 position
# Saved image 531 to h5 file in 2782 position
# Saved image 532 to h5 file in 714 position
# Saved image 533 to h5 file in 2083 position
# Saved image 534 to h5 file in 1990 position
# Saved image 535 to h5 file in 1773 position
# Saved image 536 to h5 file in 82 position
# Saved image 537 to h5 file in 1202 position
# Saved image 538 to h5 file in 1309 position
# Saved image 539 to h5 file in 500 position
# Saved image 540 to h5 file in 1631 position
# Saved image 541 to h5 file in 66 position
# Saved image 542 to h5 file in 270 position
# Saved image 543 to h5 file in 2337 position
# Saved image 544 to h5 file in 346 position
# Saved image 545 to h5 file in 2564 position
# Saved image 546 to h5 file in 1146 position
# Saved image 547 to h5 file in 1112 position
# Saved image 548 to h5 file in 2828 position
# Saved image 549 to h5 file in 575 position
# Saved image 550 to h5 file in 1669 position
# Saved image 551 to h5 file in 1343 position
# Saved image 552 to h5 file in 1891 position
# Saved image 553 to h5 file in 1044 position
# Saved image 554 to h5 file in 1426 position
# Saved image 555 to h5 file in 1537 position
# Saved image 556 to h5 file in 276 position
# Saved image 557 to h5 file in 1825 position
# Saved image 558 to h5 file in 141 position
# Saved image 559 to h5 file in 851 position
# Saved image 560 to h5 file in 2259 position
# Saved image 561 to h5 file in 2115 position
# Saved image 562 to h5 file in 785 position
# Saved image 563 to h5 file in 245 position
# Saved image 564 to h5 file in 2472 position
# Saved image 565 to h5 file in 2643 position
# Saved image 566 to h5 file in 842 position
# Saved image 567 to h5 file in 686 position
# Saved image 568 to h5 file in 1026 position
# Saved image 569 to h5 file in 2442 position
# Saved image 570 to h5 file in 2005 position
# Saved image 571 to h5 file in 2295 position
# Saved image 572 to h5 file in 1554 position
# Saved image 573 to h5 file in 2542 position
# Saved image 574 to h5 file in 2605 position
# Saved image 575 to h5 file in 1870 position
# Saved image 576 to h5 file in 265 position
# Saved image 577 to h5 file in 934 position
# Saved image 578 to h5 file in 150 position
# Saved image 579 to h5 file in 1583 position
# Saved image 580 to h5 file in 2471 position
# Saved image 581 to h5 file in 1429 position
# Saved image 582 to h5 file in 1997 position
# Saved image 583 to h5 file in 397 position
# Saved image 584 to h5 file in 872 position
# Saved image 585 to h5 file in 2815 position
# Saved image 586 to h5 file in 1159 position
# Saved image 587 to h5 file in 2254 position
# Saved image 588 to h5 file in 1161 position
# Saved image 589 to h5 file in 1817 position
# Saved image 590 to h5 file in 477 position
# Saved image 591 to h5 file in 1123 position
# Saved image 592 to h5 file in 2624 position
# Saved image 593 to h5 file in 2474 position
# Saved image 594 to h5 file in 1045 position
# Saved image 595 to h5 file in 1372 position
# Saved image 596 to h5 file in 2591 position
# Saved image 597 to h5 file in 742 position
# Saved image 598 to h5 file in 2274 position
# Saved image 599 to h5 file in 175 position
# Saved image 600 to h5 file in 2144 position
# Saved image 601 to h5 file in 2462 position
# Saved image 602 to h5 file in 1415 position
# Saved image 603 to h5 file in 2124 position
# Saved image 604 to h5 file in 979 position
# Saved image 605 to h5 file in 2768 position
# Saved image 606 to h5 file in 47 position
# Saved image 607 to h5 file in 25 position
# Saved image 608 to h5 file in 2279 position
# Saved image 609 to h5 file in 94 position
# Saved image 610 to h5 file in 533 position
# Saved image 611 to h5 file in 2426 position
# Saved image 612 to h5 file in 2053 position
# Saved image 613 to h5 file in 2359 position
# Saved image 614 to h5 file in 2726 position
# Saved image 615 to h5 file in 2658 position
# Saved image 616 to h5 file in 1819 position
# Saved image 617 to h5 file in 1668 position
# Saved image 618 to h5 file in 2006 position
# Saved image 619 to h5 file in 794 position
# Saved image 620 to h5 file in 1384 position
# Saved image 621 to h5 file in 2287 position
# Saved image 622 to h5 file in 619 position
# Saved image 623 to h5 file in 1730 position
# Saved image 624 to h5 file in 737 position
# Saved image 625 to h5 file in 1295 position
# Saved image 626 to h5 file in 1856 position
# Saved image 627 to h5 file in 1884 position
# Saved image 628 to h5 file in 1325 position
# Saved image 629 to h5 file in 427 position
# Saved image 630 to h5 file in 340 position
# Saved image 631 to h5 file in 1331 position
# Saved image 632 to h5 file in 1118 position
# Saved image 633 to h5 file in 1551 position
# Saved image 634 to h5 file in 2659 position
# Saved image 635 to h5 file in 752 position
# Saved image 636 to h5 file in 2666 position
# Saved image 637 to h5 file in 2263 position
# Saved image 638 to h5 file in 1558 position
# Saved image 639 to h5 file in 230 position
# Saved image 640 to h5 file in 108 position
# Saved image 641 to h5 file in 781 position
# Saved image 642 to h5 file in 2554 position
# Saved image 643 to h5 file in 137 position
# Saved image 644 to h5 file in 559 position
# Saved image 645 to h5 file in 207 position
# Saved image 646 to h5 file in 174 position
# Saved image 647 to h5 file in 484 position
# Saved image 648 to h5 file in 1585 position
# Saved image 649 to h5 file in 1176 position
# Saved image 650 to h5 file in 2568 position
# Saved image 651 to h5 file in 2806 position
# Saved image 652 to h5 file in 2356 position
# Saved image 653 to h5 file in 928 position
# Saved image 654 to h5 file in 2330 position
# Saved image 655 to h5 file in 459 position
# Saved image 656 to h5 file in 1070 position
# Saved image 657 to h5 file in 1902 position
# Saved image 658 to h5 file in 835 position
# Saved image 659 to h5 file in 2563 position
# Saved image 660 to h5 file in 2283 position
# Saved image 661 to h5 file in 1958 position
# Saved image 662 to h5 file in 2366 position
# Saved image 663 to h5 file in 512 position
# Saved image 664 to h5 file in 439 position
# Saved image 665 to h5 file in 1467 position
# Saved image 666 to h5 file in 1025 position
# Saved image 667 to h5 file in 725 position
# Saved image 668 to h5 file in 2141 position
# Saved image 669 to h5 file in 1998 position
# Saved image 670 to h5 file in 88 position
# Saved image 671 to h5 file in 1262 position
# Saved image 672 to h5 file in 2735 position
# Saved image 673 to h5 file in 1707 position
# Saved image 674 to h5 file in 1760 position
# Saved image 675 to h5 file in 1765 position
# Saved image 676 to h5 file in 415 position
# Saved image 677 to h5 file in 147 position
# Saved image 678 to h5 file in 520 position
# Saved image 679 to h5 file in 205 position
# Saved image 680 to h5 file in 27 position
# Saved image 681 to h5 file in 1600 position
# Saved image 682 to h5 file in 549 position
# Saved image 683 to h5 file in 1675 position
# Saved image 684 to h5 file in 2479 position
# Saved image 685 to h5 file in 994 position
# Saved image 686 to h5 file in 2712 position
# Saved image 687 to h5 file in 316 position
# Saved image 688 to h5 file in 609 position
# Saved image 689 to h5 file in 770 position
# Saved image 690 to h5 file in 2277 position
# Saved image 691 to h5 file in 2822 position
# Saved image 692 to h5 file in 713 position
# Saved image 693 to h5 file in 1614 position
# Saved image 694 to h5 file in 1119 position
# Saved image 695 to h5 file in 1790 position
# Saved image 696 to h5 file in 177 position
# Saved image 697 to h5 file in 1687 position
# Saved image 698 to h5 file in 925 position
# Saved image 699 to h5 file in 560 position
# Saved image 700 to h5 file in 1201 position
# Saved image 701 to h5 file in 1433 position
# Saved image 702 to h5 file in 879 position
# Saved image 703 to h5 file in 1018 position
# Saved image 704 to h5 file in 1930 position
# Saved image 705 to h5 file in 1496 position
# Saved image 706 to h5 file in 638 position
# Saved image 707 to h5 file in 820 position
# Saved image 708 to h5 file in 991 position
# Saved image 709 to h5 file in 481 position
# Saved image 710 to h5 file in 21 position
# Saved image 711 to h5 file in 1254 position
# Saved image 712 to h5 file in 924 position
# Saved image 713 to h5 file in 389 position
# Saved image 714 to h5 file in 2199 position
# Saved image 715 to h5 file in 2688 position
# Saved image 716 to h5 file in 2044 position
# Saved image 717 to h5 file in 396 position
# Saved image 718 to h5 file in 181 position
# Saved image 719 to h5 file in 1650 position
# Saved image 720 to h5 file in 869 position
# Saved image 721 to h5 file in 2080 position
# Saved image 722 to h5 file in 2521 position
# Saved image 723 to h5 file in 1073 position
# Saved image 724 to h5 file in 160 position
# Saved image 725 to h5 file in 1351 position
# Saved image 726 to h5 file in 1702 position
# Saved image 727 to h5 file in 2798 position
# Saved image 728 to h5 file in 2187 position
# Saved image 729 to h5 file in 168 position
# Saved image 730 to h5 file in 482 position
# Saved image 731 to h5 file in 2508 position
# Saved image 732 to h5 file in 2386 position
# Saved image 733 to h5 file in 2224 position
# Saved image 734 to h5 file in 1126 position
# Saved image 735 to h5 file in 338 position
# Saved image 736 to h5 file in 1522 position
# Saved image 737 to h5 file in 1569 position
# Saved image 738 to h5 file in 1021 position
# Saved image 739 to h5 file in 1042 position
# Saved image 740 to h5 file in 2282 position
# Saved image 741 to h5 file in 681 position
# Saved image 742 to h5 file in 2537 position
# Saved image 743 to h5 file in 2817 position
# Saved image 744 to h5 file in 1284 position
# Saved image 745 to h5 file in 824 position
# Saved image 746 to h5 file in 2512 position
# Saved image 747 to h5 file in 2526 position
# Saved image 748 to h5 file in 2156 position
# Saved image 749 to h5 file in 121 position
# Saved image 750 to h5 file in 2222 position
# Saved image 751 to h5 file in 1957 position
# Saved image 752 to h5 file in 955 position
# Saved image 753 to h5 file in 371 position
# Saved image 754 to h5 file in 87 position
# Saved image 755 to h5 file in 2034 position
# Saved image 756 to h5 file in 2488 position
# Saved image 757 to h5 file in 2603 position
# Saved image 758 to h5 file in 2370 position
# Saved image 759 to h5 file in 1542 position
# Saved image 760 to h5 file in 1888 position
# Saved image 761 to h5 file in 414 position
# Saved image 762 to h5 file in 1299 position
# Saved image 763 to h5 file in 1418 position
# Saved image 764 to h5 file in 2389 position
# Saved image 765 to h5 file in 1200 position
# Saved image 766 to h5 file in 1238 position
# Saved image 767 to h5 file in 486 position
# Saved image 768 to h5 file in 2392 position
# Saved image 769 to h5 file in 2771 position
# Saved image 770 to h5 file in 1996 position
# Saved image 771 to h5 file in 2225 position
# Saved image 772 to h5 file in 621 position
# Saved image 773 to h5 file in 326 position
# Saved image 774 to h5 file in 2062 position
# Saved image 775 to h5 file in 2088 position
# Saved image 776 to h5 file in 562 position
# Saved image 777 to h5 file in 423 position
# Saved image 778 to h5 file in 1690 position
# Saved image 779 to h5 file in 2352 position
# Saved image 780 to h5 file in 897 position
# Saved image 781 to h5 file in 2439 position
# Saved image 782 to h5 file in 1361 position
# Saved image 783 to h5 file in 2612 position
# Saved image 784 to h5 file in 1665 position
# Saved image 785 to h5 file in 1306 position
# Saved image 786 to h5 file in 476 position
# Saved image 787 to h5 file in 2721 position
# Saved image 788 to h5 file in 1733 position
# Saved image 789 to h5 file in 2015 position
# Saved image 790 to h5 file in 30 position
# Saved image 791 to h5 file in 487 position
# Saved image 792 to h5 file in 1934 position
# Saved image 793 to h5 file in 1941 position
# Saved image 794 to h5 file in 516 position
# Saved image 795 to h5 file in 1613 position
# Saved image 796 to h5 file in 1696 position
# Saved image 797 to h5 file in 1241 position
# Saved image 798 to h5 file in 1518 position
# Saved image 799 to h5 file in 1177 position
# Saved image 800 to h5 file in 1949 position
# Saved image 801 to h5 file in 93 position
# Saved image 802 to h5 file in 911 position
# Saved image 803 to h5 file in 1566 position
# Saved image 804 to h5 file in 1190 position
# Saved image 805 to h5 file in 1743 position
# Saved image 806 to h5 file in 1312 position
# Saved image 807 to h5 file in 342 position
# Saved image 808 to h5 file in 1302 position
# Saved image 809 to h5 file in 974 position
# Saved image 810 to h5 file in 2116 position
# Saved image 811 to h5 file in 2018 position
# Saved image 812 to h5 file in 1008 position
# Saved image 813 to h5 file in 2842 position
# Saved image 814 to h5 file in 528 position
# Saved image 815 to h5 file in 2492 position
# Saved image 816 to h5 file in 2449 position
# Saved image 817 to h5 file in 2235 position
# Saved image 818 to h5 file in 1681 position
# Saved image 819 to h5 file in 1438 position
# Saved image 820 to h5 file in 1411 position
# Saved image 821 to h5 file in 1771 position
# Saved image 822 to h5 file in 1598 position
# Saved image 823 to h5 file in 2799 position
# Saved image 824 to h5 file in 201 position
# Saved image 825 to h5 file in 831 position
# Saved image 826 to h5 file in 67 position
# Saved image 827 to h5 file in 2051 position
# Saved image 828 to h5 file in 202 position
# Saved image 829 to h5 file in 2172 position
# Saved image 830 to h5 file in 800 position
# Saved image 831 to h5 file in 380 position
# Saved image 832 to h5 file in 2814 position
# Saved image 833 to h5 file in 1788 position
# Saved image 834 to h5 file in 1400 position
# Saved image 835 to h5 file in 2043 position
# Saved image 836 to h5 file in 698 position
# Saved image 837 to h5 file in 1932 position
# Saved image 838 to h5 file in 2732 position
# Saved image 839 to h5 file in 2314 position
# Saved image 840 to h5 file in 1726 position
# Saved image 841 to h5 file in 140 position
# Saved image 842 to h5 file in 448 position
# Saved image 843 to h5 file in 1464 position
# Saved image 844 to h5 file in 595 position
# Saved image 845 to h5 file in 1139 position
# Saved image 846 to h5 file in 279 position
# Saved image 847 to h5 file in 2454 position
# Saved image 848 to h5 file in 564 position
# Saved image 849 to h5 file in 497 position
# Saved image 850 to h5 file in 1272 position
# Saved image 851 to h5 file in 1393 position
# Saved image 852 to h5 file in 2852 position
# Saved image 853 to h5 file in 1053 position
# Saved image 854 to h5 file in 419 position
# Saved image 855 to h5 file in 1010 position
# Saved image 856 to h5 file in 2315 position
# Saved image 857 to h5 file in 96 position
# Saved image 858 to h5 file in 1832 position
# Saved image 859 to h5 file in 617 position
# Saved image 860 to h5 file in 215 position
# Saved image 861 to h5 file in 889 position
# Saved image 862 to h5 file in 2381 position
# Saved image 863 to h5 file in 2397 position
# Saved image 864 to h5 file in 1094 position
# Saved image 865 to h5 file in 24 position
# Saved image 866 to h5 file in 2722 position
# Saved image 867 to h5 file in 2516 position
# Saved image 868 to h5 file in 757 position
# Saved image 869 to h5 file in 1505 position
# Saved image 870 to h5 file in 2628 position
# Saved image 871 to h5 file in 404 position
# Saved image 872 to h5 file in 726 position
# Saved image 873 to h5 file in 636 position
# Saved image 874 to h5 file in 1734 position
# Saved image 875 to h5 file in 1652 position
# Saved image 876 to h5 file in 2495 position
# Saved image 877 to h5 file in 1058 position
# Saved image 878 to h5 file in 2694 position
# Saved image 879 to h5 file in 1805 position
# Saved image 880 to h5 file in 1102 position
# Saved image 881 to h5 file in 1066 position
# Saved image 882 to h5 file in 1541 position
# Saved image 883 to h5 file in 1602 position
# Saved image 884 to h5 file in 1876 position
# Saved image 885 to h5 file in 277 position
# Saved image 886 to h5 file in 443 position
# Saved image 887 to h5 file in 2834 position
# Saved image 888 to h5 file in 48 position
# Saved image 889 to h5 file in 2530 position
# Saved image 890 to h5 file in 2650 position
# Saved image 891 to h5 file in 2868 position
# Saved image 892 to h5 file in 702 position
# Saved image 893 to h5 file in 91 position
# Saved image 894 to h5 file in 2291 position
# Saved image 895 to h5 file in 878 position
# Saved image 896 to h5 file in 1794 position
# Saved image 897 to h5 file in 639 position
# Saved image 898 to h5 file in 1931 position
# Saved image 899 to h5 file in 1841 position
# Saved image 900 to h5 file in 1180 position
# Saved image 901 to h5 file in 384 position
# Saved image 902 to h5 file in 687 position
# Saved image 903 to h5 file in 1713 position
# Saved image 904 to h5 file in 68 position
# Saved image 905 to h5 file in 672 position
# Saved image 906 to h5 file in 216 position
# Saved image 907 to h5 file in 704 position
# Saved image 908 to h5 file in 1193 position
# Saved image 909 to h5 file in 1822 position
# Saved image 910 to h5 file in 2824 position
# Saved image 911 to h5 file in 727 position
# Saved image 912 to h5 file in 775 position
# Saved image 913 to h5 file in 949 position
# Saved image 914 to h5 file in 224 position
# Saved image 915 to h5 file in 1673 position
# Saved image 916 to h5 file in 2786 position
# Saved image 917 to h5 file in 2818 position
# Saved image 918 to h5 file in 95 position
# Saved image 919 to h5 file in 530 position
# Saved image 920 to h5 file in 670 position
# Saved image 921 to h5 file in 303 position
# Saved image 922 to h5 file in 2485 position
# Saved image 923 to h5 file in 1051 position
# Saved image 924 to h5 file in 1253 position
# Saved image 925 to h5 file in 122 position
# Saved image 926 to h5 file in 518 position
# Saved image 927 to h5 file in 110 position
# Saved image 928 to h5 file in 776 position
# Saved image 929 to h5 file in 2219 position
# Saved image 930 to h5 file in 395 position
# Saved image 931 to h5 file in 2104 position
# Saved image 932 to h5 file in 2797 position
# Saved image 933 to h5 file in 1366 position
# Saved image 934 to h5 file in 635 position
# Saved image 935 to h5 file in 1853 position
# Saved image 936 to h5 file in 113 position
# Saved image 937 to h5 file in 2751 position
# Saved image 938 to h5 file in 538 position
# Saved image 939 to h5 file in 995 position
# Saved image 940 to h5 file in 1813 position
# Saved image 941 to h5 file in 1918 position
# Saved image 942 to h5 file in 2103 position
# Saved image 943 to h5 file in 1048 position
# Saved image 944 to h5 file in 2185 position
# Saved image 945 to h5 file in 1468 position
# Saved image 946 to h5 file in 1165 position
# Saved image 947 to h5 file in 1436 position
# Saved image 948 to h5 file in 1319 position
# Saved image 949 to h5 file in 786 position
# Saved image 950 to h5 file in 1599 position
# Saved image 951 to h5 file in 255 position
# Saved image 952 to h5 file in 2189 position
# Saved image 953 to h5 file in 176 position
# Saved image 954 to h5 file in 258 position
# Saved image 955 to h5 file in 1774 position
# Saved image 956 to h5 file in 1224 position
# Saved image 957 to h5 file in 1404 position
# Saved image 958 to h5 file in 2354 position
# Saved image 959 to h5 file in 2840 position
# Saved image 960 to h5 file in 2241 position
# Saved image 961 to h5 file in 1015 position
# Saved image 962 to h5 file in 1280 position
# Saved image 963 to h5 file in 2129 position
# Saved image 964 to h5 file in 2025 position
# Saved image 965 to h5 file in 2040 position
# Saved image 966 to h5 file in 214 position
# Saved image 967 to h5 file in 471 position
# Saved image 968 to h5 file in 2071 position
# Saved image 969 to h5 file in 1481 position
# Saved image 970 to h5 file in 2341 position
# Saved image 971 to h5 file in 2674 position
# Saved image 972 to h5 file in 1428 position
# Saved image 973 to h5 file in 2736 position
# Saved image 974 to h5 file in 1577 position
# Saved image 975 to h5 file in 1225 position
# Saved image 976 to h5 file in 2065 position
# Saved image 977 to h5 file in 1667 position
# Saved image 978 to h5 file in 1749 position
# Saved image 979 to h5 file in 271 position
# Saved image 980 to h5 file in 260 position
# Saved image 981 to h5 file in 1245 position
# Saved image 982 to h5 file in 2066 position
# Saved image 983 to h5 file in 654 position
# Saved image 984 to h5 file in 1621 position
# Saved image 985 to h5 file in 2826 position
# Saved image 986 to h5 file in 705 position
# Saved image 987 to h5 file in 744 position
# Saved image 988 to h5 file in 2825 position
# Saved image 989 to h5 file in 1775 position
# Saved image 990 to h5 file in 1260 position
# Saved image 991 to h5 file in 2625 position
# Saved image 992 to h5 file in 407 position
# Saved image 993 to h5 file in 461 position
# Saved image 994 to h5 file in 517 position
# Saved image 995 to h5 file in 2844 position
# Saved image 996 to h5 file in 1012 position
# Saved image 997 to h5 file in 142 position
# Saved image 998 to h5 file in 2095 position
# Saved image 999 to h5 file in 1745 position
# Saved image 1000 to h5 file in 105 position
# Saved image 1001 to h5 file in 1816 position
# Saved image 1002 to h5 file in 2326 position
# Saved image 1003 to h5 file in 1579 position
# Saved image 1004 to h5 file in 1374 position
# Saved image 1005 to h5 file in 1954 position
# Saved image 1006 to h5 file in 1000 position
# Saved image 1007 to h5 file in 745 position
# Saved image 1008 to h5 file in 186 position
# Saved image 1009 to h5 file in 200 position
# Saved image 1010 to h5 file in 907 position
# Saved image 1011 to h5 file in 2194 position
# Saved image 1012 to h5 file in 1515 position
# Saved image 1013 to h5 file in 2420 position
# Saved image 1014 to h5 file in 1179 position
# Saved image 1015 to h5 file in 135 position
# Saved image 1016 to h5 file in 469 position
# Saved image 1017 to h5 file in 173 position
# Saved image 1018 to h5 file in 171 position
# Saved image 1019 to h5 file in 935 position
# Saved image 1020 to h5 file in 2453 position
# Saved image 1021 to h5 file in 339 position
# Saved image 1022 to h5 file in 884 position
# Saved image 1023 to h5 file in 857 position
# Saved image 1024 to h5 file in 1939 position
# Saved image 1025 to h5 file in 329 position
# Saved image 1026 to h5 file in 1714 position
# Saved image 1027 to h5 file in 618 position
# Saved image 1028 to h5 file in 37 position
# Saved image 1029 to h5 file in 1851 position
# Saved image 1030 to h5 file in 1764 position
# Saved image 1031 to h5 file in 1644 position
# Saved image 1032 to h5 file in 578 position
# Saved image 1033 to h5 file in 912 position
# Saved image 1034 to h5 file in 2256 position
# Saved image 1035 to h5 file in 1697 position
# Saved image 1036 to h5 file in 312 position
# Saved image 1037 to h5 file in 2017 position
# Saved image 1038 to h5 file in 806 position
# Saved image 1039 to h5 file in 1744 position
# Saved image 1040 to h5 file in 2775 position
# Saved image 1041 to h5 file in 2711 position
# Saved image 1042 to h5 file in 2377 position
# Saved image 1043 to h5 file in 1508 position
# Saved image 1044 to h5 file in 1133 position
# Saved image 1045 to h5 file in 2847 position
# Saved image 1046 to h5 file in 1310 position
# Saved image 1047 to h5 file in 2617 position
# Saved image 1048 to h5 file in 1022 position
# Saved image 1049 to h5 file in 2249 position
# Saved image 1050 to h5 file in 2807 position
# Saved image 1051 to h5 file in 2577 position
# Saved image 1052 to h5 file in 1772 position
# Saved image 1053 to h5 file in 1752 position
# Saved image 1054 to h5 file in 890 position
# Saved image 1055 to h5 file in 1582 position
# Saved image 1056 to h5 file in 189 position
# Saved image 1057 to h5 file in 1824 position
# Saved image 1058 to h5 file in 236 position
# Saved image 1059 to h5 file in 1089 position
# Saved image 1060 to h5 file in 2233 position
# Saved image 1061 to h5 file in 2089 position
# Saved image 1062 to h5 file in 2467 position
# Saved image 1063 to h5 file in 2143 position
# Saved image 1064 to h5 file in 1881 position
# Saved image 1065 to h5 file in 264 position
# Saved image 1066 to h5 file in 1867 position
# Saved image 1067 to h5 file in 1589 position
# Saved image 1068 to h5 file in 254 position
# Saved image 1069 to h5 file in 1281 position
# Saved image 1070 to h5 file in 462 position
# Saved image 1071 to h5 file in 1827 position
# Saved image 1072 to h5 file in 1608 position
# Saved image 1073 to h5 file in 881 position
# Saved image 1074 to h5 file in 2159 position
# Saved image 1075 to h5 file in 1152 position
# Saved image 1076 to h5 file in 101 position
# Saved image 1077 to h5 file in 2460 position
# Saved image 1078 to h5 file in 2161 position
# Saved image 1079 to h5 file in 762 position
# Saved image 1080 to h5 file in 100 position
# Saved image 1081 to h5 file in 490 position
# Saved image 1082 to h5 file in 811 position
# Saved image 1083 to h5 file in 1611 position
# Saved image 1084 to h5 file in 1561 position
# Saved image 1085 to h5 file in 777 position
# Saved image 1086 to h5 file in 2580 position
# Saved image 1087 to h5 file in 442 position
# Saved image 1088 to h5 file in 2285 position
# Saved image 1089 to h5 file in 2450 position
# Saved image 1090 to h5 file in 1023 position
# Saved image 1091 to h5 file in 188 position
# Saved image 1092 to h5 file in 1416 position
# Saved image 1093 to h5 file in 2796 position
# Saved image 1094 to h5 file in 904 position
# Saved image 1095 to h5 file in 1835 position
# Saved image 1096 to h5 file in 558 position
# Saved image 1097 to h5 file in 586 position
# Saved image 1098 to h5 file in 145 position
# Saved image 1099 to h5 file in 2706 position
# Saved image 1100 to h5 file in 1842 position
# ...
# Saved image 2512 to h5 file in 242 position
# Saved image 2513 to h5 file in 138 position
# Saved image 2514 to h5 file in 2765 position
# Saved image 2515 to h5 file in 350 position
# Saved image 2516 to h5 file in 721 position
# Saved image 2517 to h5 file in 1441 position
# Saved image 2518 to h5 file in 1886 position
# Saved image 2519 to h5 file in 2695 position
# Saved image 2520 to h5 file in 2023 position
# Saved image 2521 to h5 file in 1594 position
# Saved image 2522 to h5 file in 1049 position
# Saved image 2523 to h5 file in 1947 position
# Saved image 2524 to h5 file in 90 position
# Saved image 2525 to h5 file in 1130 position
# Saved image 2526 to h5 file in 1419 position
# Saved image 2527 to h5 file in 2783 position
# Saved image 2528 to h5 file in 2729 position
# Saved image 2529 to h5 file in 42 position
# Saved image 2530 to h5 file in 1860 position
# Saved image 2531 to h5 file in 363 position
# Saved image 2532 to h5 file in 1079 position
# Saved image 2533 to h5 file in 2749 position
# Saved image 2534 to h5 file in 309 position
# Saved image 2535 to h5 file in 2139 position
# Saved image 2536 to h5 file in 768 position
# Saved image 2537 to h5 file in 1041 position
# Saved image 2538 to h5 file in 413 position
# Saved image 2539 to h5 file in 629 position
# Saved image 2540 to h5 file in 2284 position
# Saved image 2541 to h5 file in 1975 position
# Saved image 2542 to h5 file in 650 position
# Saved image 2543 to h5 file in 1004 position
# Saved image 2544 to h5 file in 1439 position
# Saved image 2545 to h5 file in 429 position
# Saved image 2546 to h5 file in 1530 position
# Saved image 2547 to h5 file in 1210 position
# Saved image 2548 to h5 file in 1811 position
# Saved image 2549 to h5 file in 1861 position
# Saved image 2550 to h5 file in 2760 position
# Saved image 2551 to h5 file in 2754 position
# Saved image 2552 to h5 file in 812 position
# Saved image 2553 to h5 file in 2097 position
# Saved image 2554 to h5 file in 2184 position
# Saved image 2555 to h5 file in 2204 position
# Saved image 2556 to h5 file in 581 position
# Saved image 2557 to h5 file in 2552 position
# Saved image 2558 to h5 file in 313 position
# Saved image 2559 to h5 file in 470 position
# Saved image 2560 to h5 file in 1485 position
# Saved image 2561 to h5 file in 1153 position
# Saved image 2562 to h5 file in 1276 position
# Saved image 2563 to h5 file in 1096 position
# Saved image 2564 to h5 file in 2541 position
# Saved image 2565 to h5 file in 2398 position
# Saved image 2566 to h5 file in 1737 position
# Saved image 2567 to h5 file in 1563 position
# Saved image 2568 to h5 file in 1977 position
# Saved image 2569 to h5 file in 910 position
# Saved image 2570 to h5 file in 515 position
# Saved image 2571 to h5 file in 2532 position
# Saved image 2572 to h5 file in 2214 position
# Saved image 2573 to h5 file in 213 position
# Saved image 2574 to h5 file in 1535 position
# Saved image 2575 to h5 file in 723 position
# Saved image 2576 to h5 file in 969 position
# Saved image 2577 to h5 file in 2702 position
# Saved image 2578 to h5 file in 393 position
# Saved image 2579 to h5 file in 2528 position
# Saved image 2580 to h5 file in 2364 position
# Saved image 2581 to h5 file in 2709 position
# Saved image 2582 to h5 file in 1503 position
# Saved image 2583 to h5 file in 1911 position
# Saved image 2584 to h5 file in 2074 position
# Saved image 2585 to h5 file in 431 position
# Saved image 2586 to h5 file in 2588 position
# Saved image 2587 to h5 file in 172 position
# Saved image 2588 to h5 file in 2036 position
# Saved image 2589 to h5 file in 1061 position
# Saved image 2590 to h5 file in 1494 position
# Saved image 2591 to h5 file in 722 position
# Saved image 2592 to h5 file in 128 position
# Saved image 2593 to h5 file in 2092 position
# Saved image 2594 to h5 file in 682 position
# Saved image 2595 to h5 file in 2068 position
# Saved image 2596 to h5 file in 2258 position
# Saved image 2597 to h5 file in 2464 position
# Saved image 2598 to h5 file in 1106 position
# Saved image 2599 to h5 file in 1879 position
# Saved image 2600 to h5 file in 198 position
# Saved image 2601 to h5 file in 1807 position
# Saved image 2602 to h5 file in 1616 position
# Saved image 2603 to h5 file in 715 position
# Saved image 2604 to h5 file in 2001 position
# Saved image 2605 to h5 file in 659 position
# Saved image 2606 to h5 file in 489 position
# Saved image 2607 to h5 file in 275 position
# Saved image 2608 to h5 file in 626 position
# Saved image 2609 to h5 file in 1480 position
# Saved image 2610 to h5 file in 2111 position
# Saved image 2611 to h5 file in 1695 position
# Saved image 2612 to h5 file in 1039 position
# Saved image 2613 to h5 file in 1087 position
# Saved image 2614 to h5 file in 2664 position
# Saved image 2615 to h5 file in 2505 position
# Saved image 2616 to h5 file in 237 position
# Saved image 2617 to h5 file in 1893 position
# Saved image 2618 to h5 file in 2301 position
# Saved image 2619 to h5 file in 2781 position
# Saved image 2620 to h5 file in 233 position
# Saved image 2621 to h5 file in 2087 position
# Saved image 2622 to h5 file in 774 position
# Saved image 2623 to h5 file in 589 position
# Saved image 2624 to h5 file in 1872 position
# Saved image 2625 to h5 file in 1427 position
# Saved image 2626 to h5 file in 2657 position
# Saved image 2627 to h5 file in 1797 position
# Saved image 2628 to h5 file in 1084 position
# Saved image 2629 to h5 file in 352 position
# Saved image 2630 to h5 file in 848 position
# Saved image 2631 to h5 file in 874 position
# Saved image 2632 to h5 file in 2678 position
# Saved image 2633 to h5 file in 1706 position
# Saved image 2634 to h5 file in 1711 position
# Saved image 2635 to h5 file in 2784 position
# Saved image 2636 to h5 file in 77 position
# Saved image 2637 to h5 file in 463 position
# Saved image 2638 to h5 file in 2054 position
# Saved image 2639 to h5 file in 2742 position
# Saved image 2640 to h5 file in 447 position
# Saved image 2641 to h5 file in 1270 position
# Saved image 2642 to h5 file in 2142 position
# Saved image 2643 to h5 file in 1899 position
# Saved image 2644 to h5 file in 1719 position
# Saved image 2645 to h5 file in 1398 position
# Saved image 2646 to h5 file in 1323 position
# Saved image 2647 to h5 file in 2212 position
# Saved image 2648 to h5 file in 724 position
# Saved image 2649 to h5 file in 69 position
# Saved image 2650 to h5 file in 2275 position
# Saved image 2651 to h5 file in 1626 position
# Saved image 2652 to h5 file in 2405 position
# Saved image 2653 to h5 file in 378 position
# Saved image 2654 to h5 file in 1972 position
# Saved image 2655 to h5 file in 455 position
# Saved image 2656 to h5 file in 927 position
# Saved image 2657 to h5 file in 493 position
# Saved image 2658 to h5 file in 1723 position
# Saved image 2659 to h5 file in 965 position
# Saved image 2660 to h5 file in 2202 position
# Saved image 2661 to h5 file in 1725 position
# Saved image 2662 to h5 file in 1556 position
# Saved image 2663 to h5 file in 2079 position
# Saved image 2664 to h5 file in 2 position
# Saved image 2665 to h5 file in 2641 position
# Saved image 2666 to h5 file in 63 position
# Saved image 2667 to h5 file in 527 position
# Saved image 2668 to h5 file in 2441 position
# Saved image 2669 to h5 file in 964 position
# Saved image 2670 to h5 file in 2125 position
# Saved image 2671 to h5 file in 780 position
# Saved image 2672 to h5 file in 1769 position
# Saved image 2673 to h5 file in 2307 position
# Saved image 2674 to h5 file in 1006 position
# Saved image 2675 to h5 file in 2003 position
# Saved image 2676 to h5 file in 765 position
# Saved image 2677 to h5 file in 923 position
# Saved image 2678 to h5 file in 2589 position
# Saved image 2679 to h5 file in 2367 position
# Saved image 2680 to h5 file in 0 position
# Saved image 2681 to h5 file in 2652 position
# Saved image 2682 to h5 file in 377 position
# Saved image 2683 to h5 file in 2864 position
# Saved image 2684 to h5 file in 631 position
# Saved image 2685 to h5 file in 2570 position
# Saved image 2686 to h5 file in 1001 position
# Saved image 2687 to h5 file in 931 position
# Saved image 2688 to h5 file in 1928 position
# Saved image 2689 to h5 file in 585 position
# Saved image 2690 to h5 file in 1127 position
# Saved image 2691 to h5 file in 830 position
# Saved image 2692 to h5 file in 51 position
# Saved image 2693 to h5 file in 1580 position
# Saved image 2694 to h5 file in 592 position
# Saved image 2695 to h5 file in 939 position
# Saved image 2696 to h5 file in 2028 position
# Saved image 2697 to h5 file in 246 position
# Saved image 2698 to h5 file in 1531 position
# Saved image 2699 to h5 file in 1525 position
# Saved image 2700 to h5 file in 301 position
# Saved image 2701 to h5 file in 1703 position
# Saved image 2702 to h5 file in 799 position
# Saved image 2703 to h5 file in 2592 position
# Saved image 2704 to h5 file in 1574 position
# Saved image 2705 to h5 file in 2727 position
# Saved image 2706 to h5 file in 85 position
# Saved image 2707 to h5 file in 2753 position
# Saved image 2708 to h5 file in 2849 position
# Saved image 2709 to h5 file in 1430 position
# Saved image 2710 to h5 file in 2858 position
# Saved image 2711 to h5 file in 123 position
# Saved image 2712 to h5 file in 178 position
# Saved image 2713 to h5 file in 847 position
# Saved image 2714 to h5 file in 2247 position
# Saved image 2715 to h5 file in 251 position
# Saved image 2716 to h5 file in 1198 position
# Saved image 2717 to h5 file in 1750 position
# Saved image 2718 to h5 file in 852 position
# Saved image 2719 to h5 file in 2347 position
# Saved image 2720 to h5 file in 2456 position
# Saved image 2721 to h5 file in 2308 position
# Saved image 2722 to h5 file in 1236 position
# Saved image 2723 to h5 file in 249 position
# Saved image 2724 to h5 file in 966 position
# Saved image 2725 to h5 file in 891 position
# Saved image 2726 to h5 file in 1701 position
# Saved image 2727 to h5 file in 2135 position
# Saved image 2728 to h5 file in 2237 position
# Saved image 2729 to h5 file in 1607 position
# Saved image 2730 to h5 file in 2812 position
# Saved image 2731 to h5 file in 2576 position
# Saved image 2732 to h5 file in 39 position
# Saved image 2733 to h5 file in 2226 position
# Saved image 2734 to h5 file in 583 position
# Saved image 2735 to h5 file in 709 position
# Saved image 2736 to h5 file in 1205 position
# Saved image 2737 to h5 file in 941 position
# Saved image 2738 to h5 file in 2292 position
# Saved image 2739 to h5 file in 972 position
# Saved image 2740 to h5 file in 1046 position
# Saved image 2741 to h5 file in 707 position
# Saved image 2742 to h5 file in 2022 position
# Saved image 2743 to h5 file in 1129 position
# Saved image 2744 to h5 file in 587 position
# Saved image 2745 to h5 file in 2158 position
# Saved image 2746 to h5 file in 1341 position
# Saved image 2747 to h5 file in 1946 position
# Saved image 2748 to h5 file in 114 position
# Saved image 2749 to h5 file in 2343 position
# Saved image 2750 to h5 file in 356 position
# Saved image 2751 to h5 file in 2561 position
# Saved image 2752 to h5 file in 1693 position
# Saved image 2753 to h5 file in 496 position
# Saved image 2754 to h5 file in 341 position
# Saved image 2755 to h5 file in 444 position
# Saved image 2756 to h5 file in 1391 position
# Saved image 2757 to h5 file in 1424 position
# Saved image 2758 to h5 file in 1132 position
# Saved image 2759 to h5 file in 1326 position
# Saved image 2760 to h5 file in 43 position
# Saved image 2761 to h5 file in 124 position
# Saved image 2762 to h5 file in 1136 position
# Saved image 2763 to h5 file in 1122 position
# Saved image 2764 to h5 file in 2180 position
# Saved image 2765 to h5 file in 2429 position
# Saved image 2766 to h5 file in 529 position
# Saved image 2767 to h5 file in 913 position
# Saved image 2768 to h5 file in 1003 position
# Saved image 2769 to h5 file in 358 position
# Saved image 2770 to h5 file in 1877 position
# Saved image 2771 to h5 file in 711 position
# Saved image 2772 to h5 file in 2281 position
# Saved image 2773 to h5 file in 2645 position
# Saved image 2774 to h5 file in 475 position
# Saved image 2775 to h5 file in 2414 position
# Saved image 2776 to h5 file in 149 position
# Saved image 2777 to h5 file in 1553 position
# Saved image 2778 to h5 file in 2353 position
# Saved image 2779 to h5 file in 41 position
# Saved image 2780 to h5 file in 2853 position
# Saved image 2781 to h5 file in 1470 position
# Saved image 2782 to h5 file in 1297 position
# Saved image 2783 to h5 file in 2127 position
# Saved image 2784 to h5 file in 865 position
# Saved image 2785 to h5 file in 2741 position
# Saved image 2786 to h5 file in 1738 position
# Saved image 2787 to h5 file in 240 position
# Saved image 2788 to h5 file in 2595 position
# Saved image 2789 to h5 file in 1868 position
# Saved image 2790 to h5 file in 951 position
# Saved image 2791 to h5 file in 1948 position
# Saved image 2792 to h5 file in 1078 position
# Saved image 2793 to h5 file in 2188 position
# Saved image 2794 to h5 file in 162 position
# Saved image 2795 to h5 file in 679 position
# Saved image 2796 to h5 file in 1195 position
# Saved image 2797 to h5 file in 2547 position
# Saved image 2798 to h5 file in 259 position
# Saved image 2799 to h5 file in 2865 position
# Saved image 2800 to h5 file in 2687 position
# Saved image 2801 to h5 file in 1377 position
# Saved image 2802 to h5 file in 807 position
# Saved image 2803 to h5 file in 50 position
# Saved image 2804 to h5 file in 1917 position
# Saved image 2805 to h5 file in 1242 position
# Saved image 2806 to h5 file in 1625 position
# Saved image 2807 to h5 file in 2339 position
# Saved image 2808 to h5 file in 2322 position
# Saved image 2809 to h5 file in 2601 position
# Saved image 2810 to h5 file in 1099 position
# Saved image 2811 to h5 file in 1259 position
# Saved image 2812 to h5 file in 522 position
# Saved image 2813 to h5 file in 2246 position
# Saved image 2814 to h5 file in 1632 position
# Saved image 2815 to h5 file in 2517 position
# Saved image 2816 to h5 file in 2094 position
# Saved image 2817 to h5 file in 1381 position
# Saved image 2818 to h5 file in 1420 position
# Saved image 2819 to h5 file in 2329 position
# Saved image 2820 to h5 file in 1314 position
# Saved image 2821 to h5 file in 1300 position
# Saved image 2822 to h5 file in 2434 position
# Saved image 2823 to h5 file in 1121 position
# Saved image 2824 to h5 file in 657 position
# Saved image 2825 to h5 file in 2157 position
# Saved image 2826 to h5 file in 1830 position
# Saved image 2827 to h5 file in 466 position
# Saved image 2828 to h5 file in 747 position
# Saved image 2829 to h5 file in 2136 position
# Saved image 2830 to h5 file in 1793 position
# Saved image 2831 to h5 file in 2267 position
# Saved image 2832 to h5 file in 2725 position
# Saved image 2833 to h5 file in 74 position
# Saved image 2834 to h5 file in 218 position
# Saved image 2835 to h5 file in 1777 position
# Saved image 2836 to h5 file in 83 position
# Saved image 2837 to h5 file in 1385 position
# Saved image 2838 to h5 file in 81 position
# Saved image 2839 to h5 file in 526 position
# Saved image 2840 to h5 file in 294 position
# Saved image 2841 to h5 file in 1836 position
# Saved image 2842 to h5 file in 2192 position
# Saved image 2843 to h5 file in 2149 position
# Saved image 2844 to h5 file in 888 position
# Saved image 2845 to h5 file in 10 position
# Saved image 2846 to h5 file in 1062 position
# Saved image 2847 to h5 file in 1332 position
# Saved image 2848 to h5 file in 2122 position
# Saved image 2849 to h5 file in 1829 position
# Saved image 2850 to h5 file in 298 position
# Saved image 2851 to h5 file in 2761 position
# Saved image 2852 to h5 file in 1486 position
# Saved image 2853 to h5 file in 440 position
# Saved image 2854 to h5 file in 2569 position
# Saved image 2855 to h5 file in 2321 position
# Saved image 2856 to h5 file in 1717 position
# Saved image 2857 to h5 file in 1624 position
# Saved image 2858 to h5 file in 1019 position
# Saved image 2859 to h5 file in 688 position
# Saved image 2860 to h5 file in 1938 position
# Saved image 2861 to h5 file in 648 position
# Saved image 2862 to h5 file in 1950 position
# Saved image 2863 to h5 file in 996 position
# Saved image 2864 to h5 file in 1562 position
# Saved image 2865 to h5 file in 1511 position
# Saved image 2866 to h5 file in 696 position
# Saved image 2867 to h5 file in 2269 position
# Saved image 2868 to h5 file in 764 position
# Saved image 2869 to h5 file in 405 position

# %% [markdown]
# Call the previous function, we specify the path to the testing data folder and also specify the name 'dataset_testing.h5'

# %%
image_hdf5_from_directory('Dataset/Testing', name_hdf5_file = 'dataset_testing.h5')
# Out:
# Saved image 0 to h5 file in 76 position
# Saved image 1 to h5 file in 351 position
# Saved image 2 to h5 file in 124 position
# Saved image 3 to h5 file in 185 position
# Saved image 4 to h5 file in 158 position
# Saved image 5 to h5 file in 217 position
# Saved image 6 to h5 file in 380 position
# Saved image 7 to h5 file in 212 position
# Saved image 8 to h5 file in 390 position
# Saved image 9 to h5 file in 49 position
# Saved image 10 to h5 file in 70 position
# Saved image 11 to h5 file in 159 position
# Saved image 12 to h5 file in 108 position
# Saved image 13 to h5 file in 63 position
# Saved image 14 to h5 file in 153 position
# Saved image 15 to h5 file in 292 position
# Saved image 16 to h5 file in 116 position
# Saved image 17 to h5 file in 84 position
# Saved image 18 to h5 file in 23 position
# Saved image 19 to h5 file in 3 position
# Saved image 20 to h5 file in 271 position
# Saved image 21 to h5 file in 60 position
# Saved image 22 to h5 file in 281 position
# Saved image 23 to h5 file in 55 position
# Saved image 24 to h5 file in 169 position
# Saved image 25 to h5 file in 16 position
# Saved image 26 to h5 file in 244 position
# Saved image 27 to h5 file in 302 position
# Saved image 28 to h5 file in 321 position
# Saved image 29 to h5 file in 218 position
# Saved image 30 to h5 file in 193 position
# Saved image 31 to h5 file in 126 position
# Saved image 32 to h5 file in 313 position
# Saved image 33 to h5 file in 375 position
# Saved image 34 to h5 file in 188 position
# Saved image 35 to h5 file in 152 position
# Saved image 36 to h5 file in 275 position
# Saved image 37 to h5 file in 289 position
# Saved image 38 to h5 file in 123 position
# Saved image 39 to h5 file in 354 position
# Saved image 40 to h5 file in 36 position
# Saved image 41 to h5 file in 333 position
# Saved image 42 to h5 file in 39 position
# Saved image 43 to h5 file in 226 position
# Saved image 44 to h5 file in 253 position
# Saved image 45 to h5 file in 118 position
# Saved image 46 to h5 file in 296 position
# Saved image 47 to h5 file in 97 position
# Saved image 48 to h5 file in 319 position
# Saved image 49 to h5 file in 1 position
# Saved image 50 to h5 file in 22 position
# Saved image 51 to h5 file in 41 position
# Saved image 52 to h5 file in 358 position
# Saved image 53 to h5 file in 14 position
# Saved image 54 to h5 file in 329 position
# Saved image 55 to h5 file in 34 position
# Saved image 56 to h5 file in 210 position
# Saved image 57 to h5 file in 238 position
# Saved image 58 to h5 file in 163 position
# Saved image 59 to h5 file in 361 position
# Saved image 60 to h5 file in 391 position
# Saved image 61 to h5 file in 28 position
# Saved image 62 to h5 file in 110 position
# Saved image 63 to h5 file in 143 position
# Saved image 64 to h5 file in 166 position
# Saved image 65 to h5 file in 268 position
# Saved image 66 to h5 file in 99 position
# Saved image 67 to h5 file in 183 position
# Saved image 68 to h5 file in 320 position
# Saved image 69 to h5 file in 106 position
# Saved image 70 to h5 file in 7 position
# Saved image 71 to h5 file in 371 position
# Saved image 72 to h5 file in 327 position
# Saved image 73 to h5 file in 42 position
# Saved image 74 to h5 file in 103 position
# Saved image 75 to h5 file in 89 position
# Saved image 76 to h5 file in 205 position
# Saved image 77 to h5 file in 223 position
# Saved image 78 to h5 file in 105 position
# Saved image 79 to h5 file in 75 position
# Saved image 80 to h5 file in 61 position
# Saved image 81 to h5 file in 194 position
# Saved image 82 to h5 file in 251 position
# Saved image 83 to h5 file in 318 position
# Saved image 84 to h5 file in 298 position
# Saved image 85 to h5 file in 81 position
# Saved image 86 to h5 file in 388 position
# Saved image 87 to h5 file in 353 position
# Saved image 88 to h5 file in 242 position
# Saved image 89 to h5 file in 90 position
# Saved image 90 to h5 file in 215 position
# Saved image 91 to h5 file in 111 position
# Saved image 92 to h5 file in 328 position
# Saved image 93 to h5 file in 20 position
# Saved image 94 to h5 file in 342 position
# Saved image 95 to h5 file in 175 position
# Saved image 96 to h5 file in 137 position
# Saved image 97 to h5 file in 203 position
# Saved image 98 to h5 file in 270 position
# Saved image 99 to h5 file in 343 position
# Saved image 100 to h5 file in 305 position
# Saved image 101 to h5 file in 138 position
# Saved image 102 to h5 file in 62 position
# Saved image 103 to h5 file in 230 position
# Saved image 104 to h5 file in 148 position
# Saved image 105 to h5 file in 274 position
# Saved image 106 to h5 file in 187 position
# Saved image 107 to h5 file in 0 position
# Saved image 108 to h5 file in 366 position
# Saved image 109 to h5 file in 222 position
# Saved image 110 to h5 file in 341 position
# Saved image 111 to h5 file in 67 position
# Saved image 112 to h5 file in 285 position
# Saved image 113 to h5 file in 178 position
# Saved image 114 to h5 file in 220 position
# Saved image 115 to h5 file in 386 position
# Saved image 116 to h5 file in 266 position
# Saved image 117 to h5 file in 373 position
# Saved image 118 to h5 file in 98 position
# Saved image 119 to h5 file in 172 position
# Saved image 120 to h5 file in 13 position
# Saved image 121 to h5 file in 255 position
# Saved image 122 to h5 file in 15 position
# Saved image 123 to h5 file in 235 position
# Saved image 124 to h5 file in 129 position
# Saved image 125 to h5 file in 322 position
# Saved image 126 to h5 file in 197 position
# Saved image 127 to h5 file in 256 position
# Saved image 128 to h5 file in 245 position
# Saved image 129 to h5 file in 308 position
# Saved image 130 to h5 file in 149 position
# Saved image 131 to h5 file in 363 position
# Saved image 132 to h5 file in 291 position
# Saved image 133 to h5 file in 162 position
# Saved image 134 to h5 file in 349 position
# Saved image 135 to h5 file in 54 position
# Saved image 136 to h5 file in 370 position
# Saved image 137 to h5 file in 189 position
# Saved image 138 to h5 file in 74 position
# Saved image 139 to h5 file in 150 position
# Saved image 140 to h5 file in 225 position
# Saved image 141 to h5 file in 340 position
# Saved image 142 to h5 file in 66 position
# Saved image 143 to h5 file in 2 position
# Saved image 144 to h5 file in 304 position
# Saved image 145 to h5 file in 131 position
# Saved image 146 to h5 file in 141 position
# Saved image 147 to h5 file in 293 position
# Saved image 148 to h5 file in 312 position
# Saved image 149 to h5 file in 170 position
# Saved image 150 to h5 file in 156 position
# Saved image 151 to h5 file in 27 position
# Saved image 152 to h5 file in 331 position
# Saved image 153 to h5 file in 233 position
# Saved image 154 to h5 file in 339 position
# Saved image 155 to h5 file in 214 position
# Saved image 156 to h5 file in 350 position
# Saved image 157 to h5 file in 278 position
# Saved image 158 to h5 file in 144 position
# Saved image 159 to h5 file in 352 position
# Saved image 160 to h5 file in 378 position
# Saved image 161 to h5 file in 248 position
# Saved image 162 to h5 file in 100 position
# Saved image 163 to h5 file in 130 position
# Saved image 164 to h5 file in 236 position
# Saved image 165 to h5 file in 176 position
# Saved image 166 to h5 file in 82 position
# Saved image 167 to h5 file in 334 position
# Saved image 168 to h5 file in 125 position
# Saved image 169 to h5 file in 259 position
# Saved image 170 to h5 file in 165 position
# Saved image 171 to h5 file in 182 position
# Saved image 172 to h5 file in 140 position
# Saved image 173 to h5 file in 46 position
# Saved image 174 to h5 file in 267 position
# Saved image 175 to h5 file in 282 position
# Saved image 176 to h5 file in 157 position
# Saved image 177 to h5 file in 221 position
# Saved image 178 to h5 file in 192 position
# Saved image 179 to h5 file in 164 position
# Saved image 180 to h5 file in 224 position
# Saved image 181 to h5 file in 209 position
# Saved image 182 to h5 file in 181 position
# Saved image 183 to h5 file in 115 position
# Saved image 184 to h5 file in 295 position
# Saved image 185 to h5 file in 258 position
# Saved image 186 to h5 file in 94 position
# Saved image 187 to h5 file in 264 position
# Saved image 188 to h5 file in 160 position
# Saved image 189 to h5 file in 199 position
# Saved image 190 to h5 file in 234 position
# Saved image 191 to h5 file in 338 position
# Saved image 192 to h5 file in 325 position
# Saved image 193 to h5 file in 241 position
# Saved image 194 to h5 file in 376 position
# Saved image 195 to h5 file in 231 position
# Saved image 196 to h5 file in 161 position
# Saved image 197 to h5 file in 260 position
# Saved image 198 to h5 file in 294 position
# Saved image 199 to h5 file in 216 position
# Saved image 200 to h5 file in 38 position
# Saved image 201 to h5 file in 359 position
# Saved image 202 to h5 file in 95 position
# Saved image 203 to h5 file in 367 position
# Saved image 204 to h5 file in 147 position
# Saved image 205 to h5 file in 362 position
# Saved image 206 to h5 file in 146 position
# Saved image 207 to h5 file in 127 position
# Saved image 208 to h5 file in 280 position
# Saved image 209 to h5 file in 112 position
# Saved image 210 to h5 file in 243 position
# Saved image 211 to h5 file in 269 position
# Saved image 212 to h5 file in 344 position
# Saved image 213 to h5 file in 377 position
# Saved image 214 to h5 file in 323 position
# Saved image 215 to h5 file in 287 position
# Saved image 216 to h5 file in 246 position
# Saved image 217 to h5 file in 179 position
# Saved image 218 to h5 file in 265 position
# Saved image 219 to h5 file in 239 position
# Saved image 220 to h5 file in 314 position
# Saved image 221 to h5 file in 219 position
# Saved image 222 to h5 file in 17 position
# Saved image 223 to h5 file in 208 position
# Saved image 224 to h5 file in 5 position
# Saved image 225 to h5 file in 317 position
# Saved image 226 to h5 file in 57 position
# Saved image 227 to h5 file in 369 position
# Saved image 228 to h5 file in 300 position
# Saved image 229 to h5 file in 174 position
# Saved image 230 to h5 file in 277 position
# Saved image 231 to h5 file in 360 position
# Saved image 232 to h5 file in 290 position
# Saved image 233 to h5 file in 252 position
# Saved image 234 to h5 file in 204 position
# Saved image 235 to h5 file in 383 position
# Saved image 236 to h5 file in 145 position
# Saved image 237 to h5 file in 25 position
# Saved image 238 to h5 file in 389 position
# Saved image 239 to h5 file in 47 position
# Saved image 240 to h5 file in 135 position
# Saved image 241 to h5 file in 309 position
# Saved image 242 to h5 file in 191 position
# Saved image 243 to h5 file in 154 position
# Saved image 244 to h5 file in 35 position
# Saved image 245 to h5 file in 113 position
# Saved image 246 to h5 file in 357 position
# Saved image 247 to h5 file in 355 position
# Saved image 248 to h5 file in 365 position
# Saved image 249 to h5 file in 65 position
# Saved image 250 to h5 file in 91 position
# Saved image 251 to h5 file in 229 position
# Saved image 252 to h5 file in 18 position
# Saved image 253 to h5 file in 232 position
# Saved image 254 to h5 file in 202 position
# Saved image 255 to h5 file in 43 position
# Saved image 256 to h5 file in 307 position
# Saved image 257 to h5 file in 114 position
# Saved image 258 to h5 file in 346 position
# Saved image 259 to h5 file in 310 position
# Saved image 260 to h5 file in 348 position
# Saved image 261 to h5 file in 85 position
# Saved image 262 to h5 file in 196 position
# Saved image 263 to h5 file in 83 position
# Saved image 264 to h5 file in 324 position
# Saved image 265 to h5 file in 262 position
# Saved image 266 to h5 file in 40 position
# Saved image 267 to h5 file in 45 position
# Saved image 268 to h5 file in 345 position
# Saved image 269 to h5 file in 368 position
# Saved image 270 to h5 file in 151 position
# Saved image 271 to h5 file in 167 position
# Saved image 272 to h5 file in 184 position
# Saved image 273 to h5 file in 56 position
# Saved image 274 to h5 file in 133 position
# Saved image 275 to h5 file in 263 position
# Saved image 276 to h5 file in 201 position
# Saved image 277 to h5 file in 332 position
# Saved image 278 to h5 file in 326 position
# Saved image 279 to h5 file in 107 position
# Saved image 280 to h5 file in 374 position
# Saved image 281 to h5 file in 11 position
# Saved image 282 to h5 file in 12 position
# Saved image 283 to h5 file in 186 position
# Saved image 284 to h5 file in 249 position
# Saved image 285 to h5 file in 78 position
# Saved image 286 to h5 file in 88 position
# Saved image 287 to h5 file in 120 position
# Saved image 288 to h5 file in 64 position
# Saved image 289 to h5 file in 213 position
# Saved image 290 to h5 file in 337 position
# Saved image 291 to h5 file in 50 position
# Saved image 292 to h5 file in 86 position
# Saved image 293 to h5 file in 19 position
# Saved image 294 to h5 file in 211 position
# Saved image 295 to h5 file in 37 position
# Saved image 296 to h5 file in 44 position
# Saved image 297 to h5 file in 364 position
# Saved image 298 to h5 file in 247 position
# Saved image 299 to h5 file in 284 position
# Saved image 300 to h5 file in 155 position
# Saved image 301 to h5 file in 132 position
# Saved image 302 to h5 file in 381 position
# Saved image 303 to h5 file in 173 position
# Saved image 304 to h5 file in 8 position
# Saved image 305 to h5 file in 190 position
# Saved image 306 to h5 file in 68 position
# Saved image 307 to h5 file in 31 position
# Saved image 308 to h5 file in 261 position
# Saved image 309 to h5 file in 283 position
# Saved image 310 to h5 file in 104 position
# Saved image 311 to h5 file in 72 position
# Saved image 312 to h5 file in 336 position
# Saved image 313 to h5 file in 79 position
# Saved image 314 to h5 file in 21 position
# Saved image 315 to h5 file in 276 position
# Saved image 316 to h5 file in 24 position
# Saved image 317 to h5 file in 30 position
# Saved image 318 to h5 file in 372 position
# Saved image 319 to h5 file in 136 position
# Saved image 320 to h5 file in 288 position
# Saved image 321 to h5 file in 279 position
# Saved image 322 to h5 file in 206 position
# Saved image 323 to h5 file in 69 position
# Saved image 324 to h5 file in 101 position
# Saved image 325 to h5 file in 59 position
# Saved image 326 to h5 file in 384 position
# Saved image 327 to h5 file in 6 position
# Saved image 328 to h5 file in 250 position
# Saved image 329 to h5 file in 4 position
# Saved image 330 to h5 file in 198 position
# Saved image 331 to h5 file in 109 position
# Saved image 332 to h5 file in 96 position
# Saved image 333 to h5 file in 77 position
# Saved image 334 to h5 file in 117 position
# Saved image 335 to h5 file in 347 position
# Saved image 336 to h5 file in 392 position
# Saved image 337 to h5 file in 93 position
# Saved image 338 to h5 file in 26 position
# Saved image 339 to h5 file in 330 position
# Saved image 340 to h5 file in 73 position
# Saved image 341 to h5 file in 335 position
# Saved image 342 to h5 file in 48 position
# Saved image 343 to h5 file in 382 position
# Saved image 344 to h5 file in 228 position
# Saved image 345 to h5 file in 92 position
# Saved image 346 to h5 file in 272 position
# Saved image 347 to h5 file in 10 position
# Saved image 348 to h5 file in 379 position
# Saved image 349 to h5 file in 71 position
# Saved image 350 to h5 file in 58 position
# Saved image 351 to h5 file in 52 position
# Saved image 352 to h5 file in 297 position
# Saved image 353 to h5 file in 387 position
# Saved image 354 to h5 file in 29 position
# Saved image 355 to h5 file in 385 position
# Saved image 356 to h5 file in 121 position
# Saved image 357 to h5 file in 257 position
# Saved image 358 to h5 file in 240 position
# Saved image 359 to h5 file in 286 position
# Saved image 360 to h5 file in 9 position
# Saved image 361 to h5 file in 33 position
# Saved image 362 to h5 file in 142 position
# Saved image 363 to h5 file in 195 position
# Saved image 364 to h5 file in 119 position
# Saved image 365 to h5 file in 128 position
# Saved image 366 to h5 file in 303 position
# Saved image 367 to h5 file in 227 position
# Saved image 368 to h5 file in 177 position
# Saved image 369 to h5 file in 316 position
# Saved image 370 to h5 file in 51 position
# Saved image 371 to h5 file in 102 position
# Saved image 372 to h5 file in 168 position
# Saved image 373 to h5 file in 134 position
# Saved image 374 to h5 file in 356 position
# Saved image 375 to h5 file in 207 position
# Saved image 376 to h5 file in 139 position
# Saved image 377 to h5 file in 200 position
# Saved image 378 to h5 file in 299 position
# Saved image 379 to h5 file in 306 position
# Saved image 380 to h5 file in 122 position
# Saved image 381 to h5 file in 237 position
# Saved image 382 to h5 file in 311 position
# Saved image 383 to h5 file in 393 position
# Saved image 384 to h5 file in 87 position
# Saved image 385 to h5 file in 32 position
# Saved image 386 to h5 file in 80 position
# Saved image 387 to h5 file in 301 position
# Saved image 388 to h5 file in 315 position
# Saved image 389 to h5 file in 254 position
# Saved image 390 to h5 file in 53 position
# Saved image 391 to h5 file in 171 position
# Saved image 392 to h5 file in 180 position
# Saved image 393 to h5 file in 273 position
